# %% [markdown]
# # NETFLIX DATA ANALYTICS

# %%
# importing the dataset
import pandas as pd

# %%
Data = pd.read_csv("C:\\Users\\kumar\\OneDrive\\machine Learning\\netflixData.csv")
Data
# Out:
#                                    Show Id  \
# 0     cc1b6ed9-cf9e-4057-8303-34577fb54477
# 1     e2ef4e91-fb25-42ab-b485-be8e3b23dedb
# 2     b01b73b7-81f6-47a7-86d8-acb63080d525
# 3     b6611af0-f53c-4a08-9ffa-9716dc57eb9c
# 4     7f2d4170-bab8-4d75-adc2-197f7124c070
# ...                                    ...
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d
# 5963  5bed77ab-5e31-4216-8b51-44c9a35442e6
# 5964  4661ec0c-8692-4661-bc76-a96412b311fd
# 5965  145c93a7-1924-403c-a933-4ede8ad66f26
# 5966  d4613d34-cb71-4bd6-b570-fa857f02c44d
#
#                                                 Title  \
# 0                                            (Un)Well
# 1                                              #Alive
# 2                       #AnneFrank - Parallel Stories
# 3                                            #blackAF
# 4                                    #cats_the_mewvie
# ...                                               ...
# 5962                                Ø§Ù„Ù Ù…Ø¨Ø±ÙˆÙƒ
# ...

# %% [markdown]
# # Getting some basic information about the dataset
#
# 1. head()  --- to show the top 5 record of the dataset

# %%
Data.head()
# Out:
#                                 Show Id                          Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3  b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4  7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 3  Kenya Barris and his family navigate relations...
# 4  This pawesome documentary explores how our fel...
#
#                       Director  \
# 0                          NaN
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 3                          NaN
# 4             Michael Margolis
#
# ...

# %% [markdown]
# # 2. tail() --- to show the bottom 5 record of the dataset

# %%
Data.tail()
# Out:
#                                    Show Id  \
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d
# 5963  5bed77ab-5e31-4216-8b51-44c9a35442e6
# 5964  4661ec0c-8692-4661-bc76-a96412b311fd
# 5965  145c93a7-1924-403c-a933-4ede8ad66f26
# 5966  d4613d34-cb71-4bd6-b570-fa857f02c44d
#
#                                                 Title  \
# 5962                                Ø§Ù„Ù Ù…Ø¨Ø±ÙˆÙƒ
# 5963                          Ø¯ÙØ¹Ø© Ø§Ù„Ù‚Ø§Ù‡Ø±Ø©
# 5964                                     æµ·çš„å„¿å­
# 5965                              ë°˜ë“œì‹œ ìž¡ëŠ”ë‹¤
# 5966  ìµœê°•ì „ì‚¬ ë¯¸ë‹ˆíŠ¹ê³µëŒ€ : ì˜ì›…ì˜ íƒ„ìƒ
#
#                                             Description           Director  \
# 5962  On his wedding day, an arrogant, greedy accoun...  Ahmed Nader Galal
# 5963  A group of women leaves Kuwait to attend unive...                NaN
# 5964  Two brothers start a new life in Singapore, wh...                NaN
# ...

# %% [markdown]
# # 3. shape  ----- to show the number of rows and columns

# %%
Data.shape
# Out:
# (5967, 13)

# %% [markdown]
# # 4. size ------- to show number of total values(element) in dataset

# %%
Data.size
# Out:
# 77571

# %% [markdown]
# # 5. columns ------ to show the each column name

# %%
Data.columns
# Out:
# Index(['Show Id', 'Title', 'Description', 'Director', 'Genres', 'Cast',
#        'Country', 'Release Date', 'Rating', 'Duration', 'Imdb Score',
#        'Content', 'Date Added'],
#       dtype='object')

# %% [markdown]
# # 6. dtypes ----- to show the data types of each columns

# %%
Data.dtypes
# Out:
# Show Id          object
# Title            object
# Description      object
# Director         object
# Genres           object
# Cast             object
# Country          object
# Release Date    float64
# Rating           object
# Duration         object
# Imdb Score       object
# Content          object
# Date Added       object
# dtype: object

# %% [markdown]
# # 7. info() ---- to show the indexes, columns, data-type of each column, memory at  once

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5967 entries, 0 to 5966
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show Id       5967 non-null   object
#  1   Title         5967 non-null   object
#  2   Description   5967 non-null   object
#  3   Director      3903 non-null   object
#  4   Genres        5967 non-null   object
#  5   Cast          5437 non-null   object
#  6   Country       5408 non-null   object
#  7   Release Date  5964 non-null   float64
#  8   Rating        5963 non-null   object
#  9   Duration      5964 non-null   object
#  10  Imdb Score    5359 non-null   object
#  11  Content       5967 non-null   object
#  12  Date Added    4632 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 606.1+ KB

# %% [markdown]
# # Task-1- Is there any Duplicate Records in this dataset? if yes, then remove the duplicate elements
#
# duplicate()

# %%
Data.head()
# Out:
#                                 Show Id                          Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3  b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4  7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 3  Kenya Barris and his family navigate relations...
# 4  This pawesome documentary explores how our fel...
#
#                       Director  \
# 0                          NaN
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 3                          NaN
# 4             Michael Margolis
#
# ...

# %%
Data.shape
# Out:
# (5967, 13)

# %%
Data.duplicated()    # it shows the result in boolean form
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5962    False
# 5963    False
# 5964    False
# 5965    False
# 5966    False
# Length: 5967, dtype: bool

# %%
Data[Data.duplicated()]       # to check the row wise and detect the duplicate rows
# Out:
# Empty DataFrame
# Columns: [Show Id, Title, Description, Director, Genres, Cast, Country, Release Date, Rating, Duration, Imdb Score, Content, Date Added]
# Index: []

# %%
Data.drop_duplicates()   # to remove the duplicate rows permanently and show the dataset after removing the duplicate rows
# Out:
#                                    Show Id  \
# 0     cc1b6ed9-cf9e-4057-8303-34577fb54477
# 1     e2ef4e91-fb25-42ab-b485-be8e3b23dedb
# 2     b01b73b7-81f6-47a7-86d8-acb63080d525
# 3     b6611af0-f53c-4a08-9ffa-9716dc57eb9c
# 4     7f2d4170-bab8-4d75-adc2-197f7124c070
# ...                                    ...
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d
# 5963  5bed77ab-5e31-4216-8b51-44c9a35442e6
# 5964  4661ec0c-8692-4661-bc76-a96412b311fd
# 5965  145c93a7-1924-403c-a933-4ede8ad66f26
# 5966  d4613d34-cb71-4bd6-b570-fa857f02c44d
#
#                                                 Title  \
# 0                                            (Un)Well
# 1                                              #Alive
# 2                       #AnneFrank - Parallel Stories
# 3                                            #blackAF
# 4                                    #cats_the_mewvie
# ...                                               ...
# 5962                                Ø§Ù„Ù Ù…Ø¨Ø±ÙˆÙƒ
# ...

# %%
Data.drop_duplicates(inplace = True)        # to remove duplicate rows permanently

# %%
Data.shape
# Out:
# (5967, 13)

# %% [markdown]
# # Task-2. Is there any null value present in any column? show with heat map.
# isnull()

# %%
Data.head()
# Out:
#                                 Show Id                          Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3  b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4  7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 3  Kenya Barris and his family navigate relations...
# 4  This pawesome documentary explores how our fel...
#
#                       Director  \
# 0                          NaN
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 3                          NaN
# 4             Michael Margolis
#
# ...

# %%
Data.isnull()    # to show where null value is present (true means null value and false means not null value)
# Out:
#       Show Id  Title  Description  Director  Genres   Cast  Country  \
# 0       False  False        False      True   False   True    False
# 1       False  False        False     False   False  False    False
# 2       False  False        False     False   False  False    False
# 3       False  False        False      True   False  False    False
# 4       False  False        False     False   False   True    False
# ...       ...    ...          ...       ...     ...    ...      ...
# 5962    False  False        False     False   False  False    False
# 5963    False  False        False      True   False  False     True
# 5964    False  False        False      True   False  False     True
# 5965    False  False        False     False   False  False    False
# 5966    False  False        False     False   False  False     True
#
#       Release Date  Rating  Duration  Imdb Score  Content  Date Added
# 0            False   False     False       False    False        True
# ...

# %%
Data.isnull().sum()  # to show the count of null values in each column
# Out:
# Show Id            0
# Title              0
# Description        0
# Director        2064
# Genres             0
# Cast             530
# Country          559
# Release Date       3
# Rating             4
# Duration           3
# Imdb Score       608
# Content            0
# Date Added      1335
# dtype: int64

# %%
Data.isnull().sum().sum()  # to show total null values in dataset
# Out:
# 5106

# %% [markdown]
# # Seaborn library (heat map)

# %%
import seaborn as sns              # importing the seaborn library

# %%
sns.heatmap(Data.isnull())          # using heatmap to show the null data
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(Data.notnull())      # to show the heatmap of not null data
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Q.1=> For 'Zindagi Na Milegi Dobara', what is the showid and who is the director of this show?
# isin()

# %%
Data.head()
# Out:
#                                 Show Id                          Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3  b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4  7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 3  Kenya Barris and his family navigate relations...
# 4  This pawesome documentary explores how our fel...
#
#                       Director  \
# 0                          NaN
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 3                          NaN
# 4             Michael Margolis
#
# ...

# %%
Data['Title']   # it will shows the all items is Title column only
# Out:
# 0                                              (Un)Well
# 1                                                #Alive
# 2                         #AnneFrank - Parallel Stories
# 3                                              #blackAF
# 4                                      #cats_the_mewvie
#                              ...
# 5962                                  Ø§Ù„Ù Ù…Ø¨Ø±ÙˆÙƒ
# 5963                            Ø¯ÙØ¹Ø© Ø§Ù„Ù‚Ø§Ù‡Ø±Ø©
# 5964                                       æµ·çš„å„¿å­
# 5965                                ë°˜ë“œì‹œ ìž¡ëŠ”ë‹¤
# 5966    ìµœê°•ì „ì‚¬ ë¯¸ë‹ˆíŠ¹ê³µëŒ€ : ì˜ì›…ì˜ íƒ„ìƒ
# Name: Title, Length: 5967, dtype: object

# %%
Data['Title'].isin(['Zindagi Na Milegi Dobara'])  # it show the title column in boolean form
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5962    False
# 5963    False
# 5964    False
# 5965    False
# 5966    False
# Name: Title, Length: 5967, dtype: bool

# %%
Data[Data['Title'].isin(['Zindagi Na Milegi Dobara'])]  # to show all record of a particular item in any column
# Out:
#                                    Show Id                     Title  \
# 5947  4ade696d-f3bb-47f2-bea6-ce13bb7e2a5e  Zindagi Na Milegi Dobara
#
#                                             Description     Director  \
# 5947  Three friends on an adventurous road trip/bach...  Zoya Akhtar
#
#                                       Genres  \
# 5947  Comedies, Dramas, International Movies
#
#                                                    Cast Country  Release Date  \
# 5947  Hrithik Roshan, Abhay Deol, Farhan Akhtar, Kat...   India        2011.0
#
#      Rating Duration Imdb Score Content         Date Added
# 5947  TV-14  154 min     8.3/10   Movie  December 15, 2019

# %% [markdown]
# # str.contains()

# %%
Data['Title'].str.contains('Zindagi Na Milegi Dobara')      # it show the title column in boolean form
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5962    False
# 5963    False
# 5964    False
# 5965    False
# 5966    False
# Name: Title, Length: 5967, dtype: bool

# %%
Data[Data['Title'].str.contains('Zindagi Na Milegi Dobara')]          # to show all record of a particular item in any column
# Out:
#                                    Show Id                     Title  \
# 5947  4ade696d-f3bb-47f2-bea6-ce13bb7e2a5e  Zindagi Na Milegi Dobara
#
#                                             Description     Director  \
# 5947  Three friends on an adventurous road trip/bach...  Zoya Akhtar
#
#                                       Genres  \
# 5947  Comedies, Dramas, International Movies
#
#                                                    Cast Country  Release Date  \
# 5947  Hrithik Roshan, Abhay Deol, Farhan Akhtar, Kat...   India        2011.0
#
#      Rating Duration Imdb Score Content         Date Added
# 5947  TV-14  154 min     8.3/10   Movie  December 15, 2019

# %% [markdown]
# # Q.2=> In which year highest number of tv shows and movie were released ? show with Bargraph.

# %%
Data.dtypes
# Out:
# Show Id          object
# Title            object
# Description      object
# Director         object
# Genres           object
# Cast             object
# Country          object
# Release Date    float64
# Rating           object
# Duration         object
# Imdb Score       object
# Content          object
# Date Added       object
# dtype: object

# %% [markdown]
# # to_datetime

# %%
Data['Date_N'] = pd.to_datetime(Data['Date Added'])

# %%
Data.head()
# Out:
#                                 Show Id                          Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
# 3  b6611af0-f53c-4a08-9ffa-9716dc57eb9c                       #blackAF
# 4  7f2d4170-bab8-4d75-adc2-197f7124c070               #cats_the_mewvie
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 3  Kenya Barris and his family navigate relations...
# 4  This pawesome documentary explores how our fel...
#
#                       Director  \
# 0                          NaN
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 3                          NaN
# 4             Michael Margolis
#
# ...

# %%
Data.dtypes
# Out:
# Show Id                 object
# Title                   object
# Description             object
# Director                object
# Genres                  object
# Cast                    object
# Country                 object
# Release Date           float64
# Rating                  object
# Duration                object
# Imdb Score              object
# Content                 object
# Date Added              object
# Date_N          datetime64[ns]
# dtype: object

# %% [markdown]
# # dt.year.value_counts()

# %%
Data['Date_N'].dt.year.value_counts()      # It count the occurence of all individual years in Date colunn.
# Out:
# 2020.0    1307
# 2021.0     942
# 2019.0     891
# 2018.0     784
# 2017.0     457
# 2016.0     174
# 2015.0      39
# 2014.0      16
# 2011.0      13
# 2013.0       5
# 2009.0       2
# 2012.0       1
# 2008.0       1
# Name: Date_N, dtype: int64

# %% [markdown]
# # Bargraph

# %%
Data['Date_N'].dt.year.value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Q.3=> How many movies and Tv shows are in the dataset? show with Bar Graph.
# groupby()

# %%
Data.head(2)
# Out:
#                                 Show Id     Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477  (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb    #Alive
#
#                                          Description Director  \
# 0  This docuseries takes a deep dive into the luc...      NaN
# 1  As a grisly virus rampages a city, a lone man ...   Cho Il
#
#                                            Genres                      Cast  \
# 0                                      Reality TV                       NaN
# 1  Horror Movies, International Movies, Thrillers  Yoo Ah-in, Park Shin-hye
#
#          Country  Release Date Rating  Duration Imdb Score  Content  \
# 0  United States        2020.0  TV-MA  1 Season     6.6/10  TV Show
# 1    South Korea        2020.0  TV-MA    99 min     6.2/10    Movie
#
#           Date Added     Date_N
# 0                NaN        NaT
# 1  September 8, 2020 2020-09-08

# %%
Data.groupby(by = 'Content').Content.count()    # To group all unique items of a column and show their count.
# Out:
# Content
# Movie      3867
# TV Show    2100
# Name: Content, dtype: int64

# %% [markdown]
# # countplot()

# %%
sns.countplot(Data['Content'])   # To show the count of all unique values of any column in the form of bar graph.
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Content', ylabel='count'>

# %% [markdown]
# # Q.4=> Show all the movies that were related in year 2000.
#
#
# creating new column

# %%
Data.head(2)
# Out:
#                                 Show Id     Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477  (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb    #Alive
#
#                                          Description Director  \
# 0  This docuseries takes a deep dive into the luc...      NaN
# 1  As a grisly virus rampages a city, a lone man ...   Cho Il
#
#                                            Genres                      Cast  \
# 0                                      Reality TV                       NaN
# 1  Horror Movies, International Movies, Thrillers  Yoo Ah-in, Park Shin-hye
#
#          Country  Release Date Rating  Duration Imdb Score  Content  \
# 0  United States        2020.0  TV-MA  1 Season     6.6/10  TV Show
# 1    South Korea        2020.0  TV-MA    99 min     6.2/10    Movie
#
#           Date Added     Date_N
# 0                NaN        NaT
# 1  September 8, 2020 2020-09-08

# %%
Data['year'] = Data['Date_N'].dt.year # to create new year column: it will consider only year.

# %%
Data.head(3)
# Out:
#                                 Show Id                          Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
#
#                       Director  \
# 0                          NaN
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
#
#                                            Genres  \
# 0                                      Reality TV
# 1  Horror Movies, International Movies, Thrillers
# 2             Documentaries, International Movies
#
#                           Cast        Country  Release Date Rating  Duration  \
# ...

# %% [markdown]
# # filtering

# %%
Data[(Data['Content'] == 'Movie') & (Data['year'] == 2000)]
# Out:
# Empty DataFrame
# Columns: [Show Id, Title, Description, Director, Genres, Cast, Country, Release Date, Rating, Duration, Imdb Score, Content, Date Added, Date_N, year]
# Index: []

# %%
Data[ (Data['Content'] == 'Movie') & (Data['year'] == 2020)]
# Out:
#                                    Show Id  \
# 1     e2ef4e91-fb25-42ab-b485-be8e3b23dedb
# 2     b01b73b7-81f6-47a7-86d8-acb63080d525
# 4     7f2d4170-bab8-4d75-adc2-197f7124c070
# 5     c293788a-41f7-49a3-a7fc-005ea33bce2b
# 6     0555e67e-f624-4a05-93e4-55c117d0056d
# ...                                    ...
# 5937  67575762-990e-4716-b6f8-7933f06a4cdd
# 5958  a006d6c6-e213-4a8b-9f57-b941e822d0c5
# 5959  29166831-eb84-4a0d-b2e0-e4c13fea7c6d
# 5961  06aab7f2-9756-4680-98cf-209b7ca86a9b
# 5962  62b8b682-f191-4c10-aa04-32319329bd8d
#
#                                         Title  \
# 1                                      #Alive
# 2               #AnneFrank - Parallel Stories
# 4                            #cats_the_mewvie
# 5                           #FriendButMarried
# 6                         #FriendButMarried 2
# ...                                       ...
# 5937                                Zaki Chan
# 5958                                     Zozo
# ...

# %% [markdown]
# # Q.5=> Show only the Title of all TV shows that were released in India only.
#
# filtering

# %%
Data.head(3)
# Out:
#                                 Show Id                          Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
#
#                       Director  \
# 0                          NaN
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
#
#                                            Genres  \
# 0                                      Reality TV
# 1  Horror Movies, International Movies, Thrillers
# 2             Documentaries, International Movies
#
#                           Cast        Country  Release Date Rating  Duration  \
# ...

# %%
Data[ (Data['Content'] == 'TV Show') & (Data['Country'] == 'India') ]['Title']
# Out:
# 245                                     AkbarÂ Birbal
# 302                                      Alma Matters
# 510                       Bad Boy Billionaires: India
# 551                                     Bard of Blood
# 622                                            Betaal
# 642                                Bhaag Beanie Bhaag
# 758                                     Bombay Begums
# 1005    ChuChu TV Nursery Rhymes & Kids Songs (Hindi)
# 1071                                  College Romance
# 1130                    Cricket Fever: Mumbai Indians
# 1256                                      Delhi Crime
# 1500                                Engineering Girls
# 1555                Fabulous Lives of Bollywood Wives
# 1807                                            GHOUL
# 1827                                     Girls Hostel
# 1981                                          Hasmukh
# 2250                                          Inmates
# ...

# %% [markdown]
# # Q.6=> show Top 10 Directors, who gave the highest number of TV shows & Movies to Nerflix?
#
# vlaue_counts()

# %%
Data.head(2)
# Out:
#                                 Show Id     Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477  (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb    #Alive
#
#                                          Description Director  \
# 0  This docuseries takes a deep dive into the luc...      NaN
# 1  As a grisly virus rampages a city, a lone man ...   Cho Il
#
#                                            Genres                      Cast  \
# 0                                      Reality TV                       NaN
# 1  Horror Movies, International Movies, Thrillers  Yoo Ah-in, Park Shin-hye
#
#          Country  Release Date Rating  Duration Imdb Score  Content  \
# 0  United States        2020.0  TV-MA  1 Season     6.6/10  TV Show
# 1    South Korea        2020.0  TV-MA    99 min     6.2/10    Movie
#
#           Date Added     Date_N    year
# 0                NaN        NaT     NaN
# 1  September 8, 2020 2020-09-08  2020.0

# %%
Data['Director'].value_counts()  # it show all directors movies
# Out:
# RaÃºl Campos, Jan Suter                  18
# Marcus Raboy                             16
# Suhas Kadav                              15
# Jay Karas                                14
# Youssef Chahine                          12
#                                          ..
# Remi Weekes                               1
# Vishnu Govindhan                          1
# Joachim Fest, Christian Herrendoerfer     1
# Lars Kaalund                              1
# Young Jun Lee                             1
# Name: Director, Length: 2993, dtype: int64

# %%
Data['Director'].value_counts().head(10)
# Out:
# RaÃºl Campos, Jan Suter    18
# Marcus Raboy               16
# Suhas Kadav                15
# Jay Karas                  14
# Youssef Chahine            12
# Cathy Garcia-Molina        12
# Jay Chapman                11
# Lance Bangs                 8
# Don Michael Paul            8
# Fernando AyllÃ³n            8
# Name: Director, dtype: int64

# %% [markdown]
# # Q.7=> Show all the Records , where "catrgory is Movie" and "types is comedies" or "Country is United Kinddom".
#
# Filtering (and, or operator)

# %%
Data.head(2)
# Out:
#                                 Show Id     Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477  (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb    #Alive
#
#                                          Description Director  \
# 0  This docuseries takes a deep dive into the luc...      NaN
# 1  As a grisly virus rampages a city, a lone man ...   Cho Il
#
#                                            Genres                      Cast  \
# 0                                      Reality TV                       NaN
# 1  Horror Movies, International Movies, Thrillers  Yoo Ah-in, Park Shin-hye
#
#          Country  Release Date Rating  Duration Imdb Score  Content  \
# 0  United States        2020.0  TV-MA  1 Season     6.6/10  TV Show
# 1    South Korea        2020.0  TV-MA    99 min     6.2/10    Movie
#
#           Date Added     Date_N    year
# 0                NaN        NaT     NaN
# 1  September 8, 2020 2020-09-08  2020.0

# %%
Data[ (Data['Content'] == 'Movie') & (Data['Genres'] == 'Comedies') | (Data['Country'] == 'United Kingdom')]
# Out:
#                                    Show Id  \
# 7     c844460f-6178-4f87-929e-80816c74ca35
# 37    5c1f674a-9d13-490a-8809-8e8477701499
# 106   cf823b12-e12c-430a-ad76-eb952d4fdf88
# 111   af010b65-e225-40f8-991b-959b2d9f350d
# 121   d103dc7e-a798-4da6-afdf-20128f91ad38
# ...                                    ...
# 5868  45761b40-bb05-4faf-bef2-276592fc274d
# 5875  10334d31-b105-4d1f-8e12-4dedfd68a1a2
# 5889  707df31d-8e25-4d6f-b4ad-fd8c53440245
# 5918  d43ca758-2e89-43af-99c4-e406e8073ab0
# 5942  8c9258d7-2ef2-4a5e-8fd4-85defa402e54
#
#                                        Title  \
# 7                               #realityhigh
# 37                                  21 Again
# 106              A Futile and Stupid Gesture
# 111   A Grand Night In: The Story of Aardman
# 121                           A Little Chaos
# ...                                      ...
# 5868                                 Work It
# 5875                  World War II in Colour
# ...

# %% [markdown]
# # Q.8=> In how many movies/shows, Tom cruise was cast?

# %%
Data.head(2)
# Out:
#                                 Show Id     Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477  (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb    #Alive
#
#                                          Description Director  \
# 0  This docuseries takes a deep dive into the luc...      NaN
# 1  As a grisly virus rampages a city, a lone man ...   Cho Il
#
#                                            Genres                      Cast  \
# 0                                      Reality TV                       NaN
# 1  Horror Movies, International Movies, Thrillers  Yoo Ah-in, Park Shin-hye
#
#          Country  Release Date Rating  Duration Imdb Score  Content  \
# 0  United States        2020.0  TV-MA  1 Season     6.6/10  TV Show
# 1    South Korea        2020.0  TV-MA    99 min     6.2/10    Movie
#
#           Date Added     Date_N    year
# 0                NaN        NaT     NaN
# 1  September 8, 2020 2020-09-08  2020.0

# %% [markdown]
# # filtering

# %%
Data['Cast'] == 'Tom cruise'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5962    False
# 5963    False
# 5964    False
# 5965    False
# 5966    False
# Name: Cast, Length: 5967, dtype: bool

# %%
Data[Data['Cast'] == 'Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [Show Id, Title, Description, Director, Genres, Cast, Country, Release Date, Rating, Duration, Imdb Score, Content, Date Added, Date_N, year]
# Index: []

# %% [markdown]
# # str.contains()

# %%
Data['Cast'].str.contains('Tom Cruise')
# Out:
# 0         NaN
# 1       False
# 2       False
# 3       False
# 4         NaN
#         ...
# 5962    False
# 5963    False
# 5964    False
# 5965    False
# 5966    False
# Name: Cast, Length: 5967, dtype: object

# %%
#Data[Data['Cast'].str.contains('Tom Cruise')]

# %% [markdown]
# # Creating new dataframe

# %%
Data_new = Data.dropna()    # it drops the rows that contains all or any missing values.

# %%
Data_new.head(2)
# Out:
#                                 Show Id                          Title  \
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
#
#                                          Description  \
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
#
#                       Director  \
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
#
#                                            Genres  \
# 1  Horror Movies, International Movies, Thrillers
# 2             Documentaries, International Movies
#
#                           Cast      Country  Release Date Rating Duration  \
# 1     Yoo Ah-in, Park Shin-hye  South Korea        2020.0  TV-MA   99 min
# 2  Helen Mirren, Gengher Gatti        Italy        2019.0  TV-14   95 min
#
#   Imdb Score Content         Date Added     Date_N    year
# ...

# %%
Data_new[Data_new['Cast'].str.contains('Tom Cruise')]
# Out:
#                                    Show Id     Title  \
# 3838  8a3c098b-386a-44e4-a3a3-c5771871597e  Rain Man
#
#                                             Description        Director  \
# 3838  Motivated by money, a selfish workaholic seeki...  Barry Levinson
#
#                       Genres  \
# 3838  Classic Movies, Dramas
#
#                                                    Cast        Country  \
# 3838  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#       Release Date Rating Duration Imdb Score Content     Date Added  \
# 3838        1988.0      R  134 min     7.9/10   Movie  March 1, 2021
#
#          Date_N    year
# 3838 2021-03-01  2021.0

# %% [markdown]
# # Q.9=> What are the different Ratings defined by Netflix?
#
# nunique() and unique() function

# %%
Data.head(2)
# Out:
#                                 Show Id     Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477  (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb    #Alive
#
#                                          Description Director  \
# 0  This docuseries takes a deep dive into the luc...      NaN
# 1  As a grisly virus rampages a city, a lone man ...   Cho Il
#
#                                            Genres                      Cast  \
# 0                                      Reality TV                       NaN
# 1  Horror Movies, International Movies, Thrillers  Yoo Ah-in, Park Shin-hye
#
#          Country  Release Date Rating  Duration Imdb Score  Content  \
# 0  United States        2020.0  TV-MA  1 Season     6.6/10  TV Show
# 1    South Korea        2020.0  TV-MA    99 min     6.2/10    Movie
#
#           Date Added     Date_N    year
# 0                NaN        NaT     NaN
# 1  September 8, 2020 2020-09-08  2020.0

# %%
Data['Rating'].unique()
# Out:
# array(['TV-MA', 'TV-14', 'TV-G', 'TV-PG', 'TV-Y', 'R', 'PG-13', 'TV-Y7',
#        'PG', 'G', nan, 'NC-17'], dtype=object)

# %%
Data['Rating'].nunique()
# Out:
# 11

# %% [markdown]
# # Q.9.1=> How many Movies got the 'TV-14' rating, in canada.

# %%
Data.head(2)
# Out:
#                                 Show Id     Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477  (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb    #Alive
#
#                                          Description Director  \
# 0  This docuseries takes a deep dive into the luc...      NaN
# 1  As a grisly virus rampages a city, a lone man ...   Cho Il
#
#                                            Genres                      Cast  \
# 0                                      Reality TV                       NaN
# 1  Horror Movies, International Movies, Thrillers  Yoo Ah-in, Park Shin-hye
#
#          Country  Release Date Rating  Duration Imdb Score  Content  \
# 0  United States        2020.0  TV-MA  1 Season     6.6/10  TV Show
# 1    South Korea        2020.0  TV-MA    99 min     6.2/10    Movie
#
#           Date Added     Date_N    year
# 0                NaN        NaT     NaN
# 1  September 8, 2020 2020-09-08  2020.0

# %%
Data[ (Data['Content'] == 'Movie') & (Data['Rating'] == 'TV-14') & (Data['Country'] == 'Canada')]
# Out:
#                                    Show Id  \
# 4     7f2d4170-bab8-4d75-adc2-197f7124c070
# 2895  65cacd6d-e99a-4432-84c3-98a3458c94e7
# 2980  3955f108-7b46-4d45-b5f0-b48aaab8b4ba
# 5344  e31cd859-eeb7-4f63-b0ae-d3b8b9c0b882
#
#                                             Title  \
# 4                                #cats_the_mewvie
# 2895   Made You Look: A True Story About Fake Art
# 2980  Martin Matte: La vie, la mort...eh la la..!
# 5344               There's Something in the Water
#
#                                             Description  \
# 4     This pawesome documentary explores how our fel...
# 2895  A woman walks into a New York gallery with a c...
# 2980  Quebecois comedy star Martin Matte serves up e...
# 5344  This documentary spotlights the struggle of mi...
#
#                     Director                               Genres  \
# 4           Michael Margolis  Documentaries, International Movies
# 2895            Barry Avrich  Documentaries, International Movies
# ...

# %%
Data[ (Data['Content'] == 'Movie') & (Data['Rating'] == 'TV-14') & (Data['Country'] == 'Canada')].shape
# Out:
# (4, 15)

# %% [markdown]
# # Q.9.2=> How many TV shows got the 'R' rating, after year 2018?

# %%
Data.head(2)
# Out:
#                                 Show Id     Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477  (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb    #Alive
#
#                                          Description Director  \
# 0  This docuseries takes a deep dive into the luc...      NaN
# 1  As a grisly virus rampages a city, a lone man ...   Cho Il
#
#                                            Genres                      Cast  \
# 0                                      Reality TV                       NaN
# 1  Horror Movies, International Movies, Thrillers  Yoo Ah-in, Park Shin-hye
#
#          Country  Release Date Rating  Duration Imdb Score  Content  \
# 0  United States        2020.0  TV-MA  1 Season     6.6/10  TV Show
# 1    South Korea        2020.0  TV-MA    99 min     6.2/10    Movie
#
#           Date Added     Date_N    year
# 0                NaN        NaT     NaN
# 1  September 8, 2020 2020-09-08  2020.0

# %%
Data [(Data['Content'] == 'TV Show') & (Data['Rating'] == 'R') & (Data['year'] > 2018) ]
# Out:
# Empty DataFrame
# Columns: [Show Id, Title, Description, Director, Genres, Cast, Country, Release Date, Rating, Duration, Imdb Score, Content, Date Added, Date_N, year]
# Index: []

# %% [markdown]
# # Q.10=> What is the Maximum duration of a Movie/show on Netflix?

# %%
Data.head(2)
# Out:
#                                 Show Id     Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477  (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb    #Alive
#
#                                          Description Director  \
# 0  This docuseries takes a deep dive into the luc...      NaN
# 1  As a grisly virus rampages a city, a lone man ...   Cho Il
#
#                                            Genres                      Cast  \
# 0                                      Reality TV                       NaN
# 1  Horror Movies, International Movies, Thrillers  Yoo Ah-in, Park Shin-hye
#
#          Country  Release Date Rating  Duration Imdb Score  Content  \
# 0  United States        2020.0  TV-MA  1 Season     6.6/10  TV Show
# 1    South Korea        2020.0  TV-MA    99 min     6.2/10    Movie
#
#           Date Added     Date_N    year
# 0                NaN        NaT     NaN
# 1  September 8, 2020 2020-09-08  2020.0

# %%
Data.Duration.unique()
# Out:
# array(['1 Season', '99 min', '95 min', '90 min', '102 min', '104 min',
#        '56 min', '125 min', '119 min', '87 min', '97 min', '109 min',
#        '44 min', '101 min', '89 min', '4 Seasons', '3 Seasons', '84 min',
#        '124 min', '114 min', '130 min', '103 min', '143 min', '107 min',
#        '158 min', '144 min', '78 min', '140 min', '135 min', '117 min',
#        '92 min', '164 min', '93 min', '91 min', '116 min', '2 Seasons',
#        '105 min', '120 min', '96 min', '75 min', '115 min', '129 min',
#        '80 min', '77 min', '148 min', '123 min', '121 min', '131 min',
#        '28 min', '122 min', '94 min', '85 min', '22 min', '86 min',
#        '137 min', '68 min', '29 min', '168 min', '21 min', '59 min',
#        '113 min', '20 min', '108 min', '111 min', '110 min', '100 min',
#        '83 min', '26 min', '156 min', '30 min', '57 min', '82 min',
#        '98 min', '133 min', '154 min', '146 min', '136 min', '106 min',
# ...

# %%
Data.Duration.nunique()
# Out:
# 207

# %% [markdown]
# # str.split()

# %%
Data[['Minutes', 'Unit']] = Data['Duration'].str.split(' ', expand = True)

# %%
Data.head(2)
# Out:
#                                 Show Id     Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477  (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb    #Alive
#
#                                          Description Director  \
# 0  This docuseries takes a deep dive into the luc...      NaN
# 1  As a grisly virus rampages a city, a lone man ...   Cho Il
#
#                                            Genres                      Cast  \
# 0                                      Reality TV                       NaN
# 1  Horror Movies, International Movies, Thrillers  Yoo Ah-in, Park Shin-hye
#
#          Country  Release Date Rating  Duration Imdb Score  Content  \
# 0  United States        2020.0  TV-MA  1 Season     6.6/10  TV Show
# 1    South Korea        2020.0  TV-MA    99 min     6.2/10    Movie
#
#           Date Added     Date_N    year Minutes    Unit
# 0                NaN        NaT     NaN       1  Season
# 1  September 8, 2020 2020-09-08  2020.0      99     min

# %%
Data.dtypes
# Out:
# Show Id                 object
# Title                   object
# Description             object
# Director                object
# Genres                  object
# Cast                    object
# Country                 object
# Release Date           float64
# Rating                  object
# Duration                object
# Imdb Score              object
# Content                 object
# Date Added              object
# Date_N          datetime64[ns]
# year                   float64
# Minutes                 object
# Unit                    object
# dtype: object

# %% [markdown]
# # Q.11=> Which Individual country as the Highest no. of TV shows?
#
# value_counts()

# %%
Data.head(2)
# Out:
#                                 Show Id     Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477  (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb    #Alive
#
#                                          Description Director  \
# 0  This docuseries takes a deep dive into the luc...      NaN
# 1  As a grisly virus rampages a city, a lone man ...   Cho Il
#
#                                            Genres                      Cast  \
# 0                                      Reality TV                       NaN
# 1  Horror Movies, International Movies, Thrillers  Yoo Ah-in, Park Shin-hye
#
#          Country  Release Date Rating  Duration Imdb Score  Content  \
# 0  United States        2020.0  TV-MA  1 Season     6.6/10  TV Show
# 1    South Korea        2020.0  TV-MA    99 min     6.2/10    Movie
#
#           Date Added     Date_N    year Minutes    Unit
# 0                NaN        NaT     NaN       1  Season
# 1  September 8, 2020 2020-09-08  2020.0      99     min

# %%
Data_tvshow = Data[Data['Content'] == 'TV Show']
Data_tvshow
# Out:
#                                    Show Id                    Title  \
# 0     cc1b6ed9-cf9e-4057-8303-34577fb54477                 (Un)Well
# 3     b6611af0-f53c-4a08-9ffa-9716dc57eb9c                 #blackAF
# 13    91c48de3-5bc6-43e8-ae4c-944a0b190687       100 Days My Prince
# 14    3ad83357-9327-48bb-b89d-862d61b5801e               100 Humans
# 20    ee4f5117-cf68-4862-b61c-310fb8c7379b           13 Reasons Why
# ...                                    ...                      ...
# 5954  e4d88cc9-8ee2-46b9-aac6-af786e6efbdb                Zona Rosa
# 5956  80bf7986-5698-4d01-bc52-e08a8210b834                      Zoo
# 5960  a86d832c-1082-4b10-82a3-766bb539e3aa    Zumbo's Just Desserts
# 5963  5bed77ab-5e31-4216-8b51-44c9a35442e6  Ø¯ÙØ¹Ø© Ø§Ù„Ù‚Ø§Ù‡Ø±Ø©
# 5964  4661ec0c-8692-4661-bc76-a96412b311fd             æµ·çš„å„¿å­
#
#                                             Description Director  \
# 0     This docuseries takes a deep dive into the luc...      NaN
# ...

# %%
Data_tvshow.head(2)
# Out:
#                                 Show Id     Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477  (Un)Well
# 3  b6611af0-f53c-4a08-9ffa-9716dc57eb9c  #blackAF
#
#                                          Description Director       Genres  \
# 0  This docuseries takes a deep dive into the luc...      NaN   Reality TV
# 3  Kenya Barris and his family navigate relations...      NaN  TV Comedies
#
#                                                 Cast        Country  \
# 0                                                NaN  United States
# 3  Kenya Barris, Rashida Jones, Iman Benson, Genn...  United States
#
#    Release Date Rating  Duration Imdb Score  Content Date Added Date_N  year  \
# 0        2020.0  TV-MA  1 Season     6.6/10  TV Show        NaN    NaT   NaN
# 3        2020.0  TV-MA  1 Season     6.6/10  TV Show        NaN    NaT   NaN
#
#   Minutes    Unit
# 0       1  Season
# 3       1  Season

# %%
Data_tvshow.Country.value_counts()
# Out:
# United States                                624
# Japan                                        154
# United Kingdom                               141
# South Korea                                  138
# Taiwan                                        62
#                                             ...
# Denmark, Singapore, Canada, United States      1
# Mexico, United States, Spain, Colombia         1
# Japan, Canada, United States                   1
# Australia, Canada                              1
# Italy, United States                           1
# Name: Country, Length: 165, dtype: int64

# %%
Data_tvshow.Country.value_counts().head(1)
# Out:
# United States    624
# Name: Country, dtype: int64

# %% [markdown]
# # Q.12=> How can we sort the dataset by year?
#
# sort_values()

# %%
Data.sort_values(by = 'year')
# Out:
#                                    Show Id                       Title  \
# 5411  b6aafb23-24a2-4328-b85e-62795a7beccf        To and From New York
# 4382  dd9b360f-f7b1-401b-8d3a-374692aed35c                    Splatter
# 2440  10a9b02d-3d83-4ed2-bf98-882553f9761a     Just Another Love Story
# 150   6fc7ebe9-3293-48fd-b556-4113899a6bc5  A Stoning in Fulham County
# 2417  434ed003-d3f5-418c-8892-fc79318fa506      Joseph: King of Dreams
# ...                                    ...                         ...
# 5945  d143fc8e-0470-4dc8-a65f-5dc59370d776            Zindagi in Short
# 5951  3eee1663-92d7-4b63-943d-bbfd66635295                  Zoids Wild
# 5954  e4d88cc9-8ee2-46b9-aac6-af786e6efbdb                   Zona Rosa
# 5963  5bed77ab-5e31-4216-8b51-44c9a35442e6     Ø¯ÙØ¹Ø© Ø§Ù„Ù‚Ø§Ù‡Ø±Ø©
# 5964  4661ec0c-8692-4661-bc76-a96412b311fd                æµ·çš„å„¿å­
#
#                                             Description  \
# 5411  While covering a story in New York City, a Sea...
# ...

# %%
Data.sort_values(by = 'year', ascending = False).head(2)
# Out:
#                                    Show Id                          Title  \
# 2058  64eccea8-7a90-452b-b34b-a85eff755e1f             High-Rise Invasion
# 949   ae51305b-5da0-49e0-8bc8-847a166500c6  Cheech & Chong's Still Smokin
#
#                                             Description     Director  \
# 2058  High schooler Yuri finds herself atop a skyscr...          NaN
# 949   Stoner comedians Cheech Marin and Tommy Chong ...  Tommy Chong
#
#                                                  Genres  \
# 2058  Anime Series, International TV Shows, TV Thril...
# 949                               Comedies, Cult Movies
#
#                                                    Cast Country  Release Date  \
# 2058  Haruka Shiraishi, Shiki Aoki, Akira Sekine, Ju...   Japan        2021.0
# 949   Cheech Marin, Tommy Chong, Susan Hahn, Carol v...     NaN        1983.0
#
#      Rating  Duration Imdb Score  Content      Date Added     Date_N    year  \
# ...

# %% [markdown]
# # Q.13=> Find all the instance where:
#     caregory is 'Movie' and types is 'Dramas'
#     or
#     Category is 'Tv show' and types is 'kids'tv'.

# %%
Data.head(2)
# Out:
#                                 Show Id     Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477  (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb    #Alive
#
#                                          Description Director  \
# 0  This docuseries takes a deep dive into the luc...      NaN
# 1  As a grisly virus rampages a city, a lone man ...   Cho Il
#
#                                            Genres                      Cast  \
# 0                                      Reality TV                       NaN
# 1  Horror Movies, International Movies, Thrillers  Yoo Ah-in, Park Shin-hye
#
#          Country  Release Date Rating  Duration Imdb Score  Content  \
# 0  United States        2020.0  TV-MA  1 Season     6.6/10  TV Show
# 1    South Korea        2020.0  TV-MA    99 min     6.2/10    Movie
#
#           Date Added     Date_N    year Minutes    Unit
# 0                NaN        NaT     NaN       1  Season
# 1  September 8, 2020 2020-09-08  2020.0      99     min

# %%
Data[ (Data['Content'] == 'Movie') & (Data['Genres'] == 'Dramas')] # 1st condition
# Out:
#                                    Show Id                       Title  \
# 150   6fc7ebe9-3293-48fd-b556-4113899a6bc5  A Stoning in Fulham County
# 195   6ebd13aa-69d0-4a89-8bcc-5739b408c027          Across Grace Alley
# 201   5a9ee713-a128-4916-862e-ea4402b05380    Adam: His Song Continues
# 298   fbb1f3b4-a39a-4d46-beea-102face22f1c            All Together Now
# 328   348f849c-b910-4fb6-8851-d5142bc32673                 American Me
# ...                                    ...                         ...
# 5443  af634325-8796-421b-b731-ce6646c0908a          Too Young the Hero
# 5549  a1f2bd97-8992-4f14-ae2e-57aae273b574       Two Distant Strangers
# 5618  91ee5b5d-0f15-4890-b2f7-dc68f48ce3fb            Unspeakable Acts
# 5667  6f085a78-2da6-49f2-b4ce-2aa4f8da94be                     Villain
# 5870  c680ae99-f34c-4fc7-9dbc-f0aabfd02d5a               Working Title
#
#                                             Description  \
# 150   After reckless teens kill an Amish child, a pr...
# ...

# %%
Data[ (Data['Content'] == 'TV Show') & (Data['Genres'] == "Kids' TV")]  # 2nd condition
# Out:
#                                    Show Id                         Title  \
# 54    e14fd618-75bb-4800-b86a-ca3af91bdd67                       44 Cats
# 179   2e98c599-e0e8-4dbd-a000-0fa3304bd9a9                  Abby Hatcher
# 429   794dc32e-1d07-467c-9d7f-0f0dc34cbbb0             Ask the StoryBots
# 526   d06e8c6e-78b0-423e-9d74-e32453d5b236                    Bal Ganesh
# 544   b49629e3-0569-4880-aefb-df8b14a69703  Barbie Dreamhouse Adventures
# ...                                    ...                           ...
# 5847  f482bda7-b520-4d49-924e-b40a20c2b919                     Winx Club
# 5866  49720d39-1b92-4bb5-83ab-0e2c09bd8608                    Word Party
# 5867  7f02dc30-8510-4b92-a6f9-10d1fef672c3              Word Party Songs
# 5873  ba96339e-eb78-4c2a-893f-ff3c52eb79de                 World of Winx
# 5933  24bb2381-4062-4188-88e4-4e9a45ba3eda                            Z4
#
#                                             Description             Director  \
# ...

# %%
Data[ (Data['Content'] == 'Movie') & (Data['Genres'] == 'Dramas') | (Data['Content'] == 'TV Show') & (Data['Genres'] == "Kids' TV")]
# Out:
#                                    Show Id                       Title  \
# 54    e14fd618-75bb-4800-b86a-ca3af91bdd67                     44 Cats
# 150   6fc7ebe9-3293-48fd-b556-4113899a6bc5  A Stoning in Fulham County
# 179   2e98c599-e0e8-4dbd-a000-0fa3304bd9a9                Abby Hatcher
# 195   6ebd13aa-69d0-4a89-8bcc-5739b408c027          Across Grace Alley
# 201   5a9ee713-a128-4916-862e-ea4402b05380    Adam: His Song Continues
# ...                                    ...                         ...
# 5866  49720d39-1b92-4bb5-83ab-0e2c09bd8608                  Word Party
# 5867  7f02dc30-8510-4b92-a6f9-10d1fef672c3            Word Party Songs
# 5870  c680ae99-f34c-4fc7-9dbc-f0aabfd02d5a               Working Title
# 5873  ba96339e-eb78-4c2a-893f-ff3c52eb79de               World of Winx
# 5933  24bb2381-4062-4188-88e4-4e9a45ba3eda                          Z4
#
#                                             Description          Director  \
# ...

# %% [markdown]
# # Project is completed
